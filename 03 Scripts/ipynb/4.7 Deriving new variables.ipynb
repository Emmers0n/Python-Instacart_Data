# %%
#Import Libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'/Users/tilemmerichs/Desktop/Insta Basket Analysis'

# %%
#Import Data frame
df1 = pd.read_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'orders_products_combined_cleaned.pkl'))

# %%
df2 = pd.read_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'orders_products_combined_cleaned.pkl'))

# %%
df = df1[:1000000]

# %%
df.shape
# Out:
# (1000000, 13)

# %%
#Defining the User-defined function
def price_label(row):
    
    if row['prices'] <= 5:
        return 'Low-range product'
    elif (row['prices'] > 5) and (row['prices'] <= 15):
        return 'Mid-range product'
    elif row['prices'] > 15:
        return 'High-range product'
    else: return'Not enough data'

# %%
#Applying the User-defined function price_label
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/zd/qkhy40x95pz8bbrzdsfzf64r0000gn/T/ipykernel_76313/2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts()
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
#Find the highest price in the subset
df['prices'].max()
# Out:
# 14.8

# %%
#This Code from the instructions did NOT work
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product' 
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
#Also this Code did NOT work
df1.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /Users/tilemmerichs/opt/anaconda3/lib/python3.9/site-packages/pandas/core/common.py:241: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = np.asarray(values, dtype=dtype)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 df1.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:712, in _LocationIndexer.__setitem__(self, key, value)
#     710 else:
#     711     key = com.apply_if_callable(key, self.obj)
# --> 712 indexer = self._get_setitem_indexer(key)
#     713 self._has_valid_setitem_indexer(key)
# ...

# %%
#Second try to make the code work
df1.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'
# Out:
# /Users/tilemmerichs/opt/anaconda3/lib/python3.9/site-packages/pandas/core/common.py:241: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = np.asarray(values, dtype=dtype)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 df1.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:712, in _LocationIndexer.__setitem__(self, key, value)
#     710 else:
#     711     key = com.apply_if_callable(key, self.obj)
# --> 712 indexer = self._get_setitem_indexer(key)
#     713 self._has_valid_setitem_indexer(key)
# ...

# %%
df1['orders_day_of_the_week'].value_counts()
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_the_week, dtype: int64

# %%
#Because the suggested code did not work, I tried to use the user-def function on the whole data frame
df1['price_range'] = df1.apply(price_label, axis=1)

# %%
df1['price_range'].value_counts()
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range, dtype: int64

# %%
result = []

for value in df1['orders_day_of_the_week']:
    if value == 0:
        result.append('Busiest day')
    elif value == 4:
        result.append('Least busy')
    else:
        result.append('Regularly busy')

# %%
print(result)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df1['Busiest_day'] = result

# %%
df1['Busiest_day'].value_counts()
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: Busiest_day, dtype: int64

# %%
df1
# Out:
#           order_id  user_id  order_number  orders_day_of_the_week  \
# 0          2539329        1             1                       2
# 1          2398795        1             2                       3
# 2           473747        1             3                       3
# 3          2254736        1             4                       4
# 4           431534        1             5                       4
# ...            ...      ...           ...                     ...
# 32404854   1320836   202557            17                       2
# 32404855     31526   202557            18                       5
# 32404856    758936   203436             1                       2
# 32404857   2745165   203436             2                       3
# 32404858   3093936   205420             1                       4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# ...

# %%
#New column with more detailed overview of the weekdays
result = []

for value in df1['orders_day_of_the_week']:
    if value == 0:
        result.append('Busiest day')
    elif value == 4:
        result.append('Least busy')
    elif value ==1:
        result.append('Second busiest day')
    elif value == 3:
        result.append('Second least busy')
    else:
        result.append('Regularly busy')

# %%
df1['Busiest_days'] = result

# %%
df1
# Out:
#           order_id  user_id  order_number  orders_day_of_the_week  \
# 0          2539329        1             1                       2
# 1          2398795        1             2                       3
# 2           473747        1             3                       3
# 3          2254736        1             4                       4
# 4           431534        1             5                       4
# ...            ...      ...           ...                     ...
# 32404854   1320836   202557            17                       2
# 32404855     31526   202557            18                       5
# 32404856    758936   203436             1                       2
# 32404857   2745165   203436             2                       3
# 32404858   3093936   205420             1                       4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# ...

# %%
#Drop the old column without the s in days
df1 = df1.drop(columns=['Busiest_day'])

# %%
df1
# Out:
#           order_id  user_id  order_number  orders_day_of_the_week  \
# 0          2539329        1             1                       2
# 1          2398795        1             2                       3
# 2           473747        1             3                       3
# 3          2254736        1             4                       4
# 4           431534        1             5                       4
# ...            ...      ...           ...                     ...
# 32404854   1320836   202557            17                       2
# 32404855     31526   202557            18                       5
# 32404856    758936   203436             1                       2
# 32404857   2745165   203436             2                       3
# 32404858   3093936   205420             1                       4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# ...

# %%
df1['Busiest_days'].value_counts()
# Out:
# Regularly busy        12916111
# Busiest day            6204182
# Second busiest day     5660230
# Second least busy      3840534
# Least busy             3783802
# Name: Busiest_days, dtype: int64

# %% [markdown]
# Task 3
# Regularly Busy are now 3 days. The busiest day makes up 50% of the Regular days and twice as much aus the least busiest day. The second least busiest day has almost as many orders as the least busiest day. The busiest day has around 10% more orders then the second busiest day.

# %%
df1['order_hour_of_day'].value_counts()
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# 0-6 least busiest hours
# 7-8 regular
# 9-16 busiest
# 17-23 regular

# %%
result2 = []
for x in df1['order_hour_of_day']:
    if (x>=0) and (x<=6):
        result2.append('Fewest orders')
    elif (x>=9) and (x<=16):
        result2.append('Most orders')
    else:
        result2.append('Average orders')

# %%
df1['busiest_period_of_day'] = result2

# %%
df1['busiest_period_of_day'].value_counts()
# Out:
# Most orders       21118071
# Average orders    10399967
# Fewest orders       886821
# Name: busiest_period_of_day, dtype: int64

# %%
df1
# Out:
#           order_id  user_id  order_number  orders_day_of_the_week  \
# 0          2539329        1             1                       2
# 1          2398795        1             2                       3
# 2           473747        1             3                       3
# 3          2254736        1             4                       4
# 4           431534        1             5                       4
# ...            ...      ...           ...                     ...
# 32404854   1320836   202557            17                       2
# 32404855     31526   202557            18                       5
# 32404856    758936   203436             1                       2
# 32404857   2745165   203436             2                       3
# 32404858   3093936   205420             1                       4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# ...

# %%
df1.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'final_ords_prods.pkl'))
