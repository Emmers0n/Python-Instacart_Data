# %%
#Import Libraries
import pandas as pd
import numpy as np
import os

# %%
path = path = r'/Users/tilemmerichs/Desktop/Insta Basket Analysis'

# %%
#Import Data frames
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'products_checked.csv'), index_col = False)
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col= False)
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'order_products_prior.csv'), index_col= False)

# %%
#Check the output
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
df_merged_large = df_ords.merge(df_ords_prior, on ='order_id', indicator = True)

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %%
df_merged_large.shape
# Out:
# (32434489, 11)

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_the_week  \
# 0           0   2539329        1             1                       2
# 1           0   2539329        1             1                       2
# 2           0   2539329        1             1                       2
# 3           0   2539329        1             1                       2
# 4           0   2539329        1             1                       2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# ...

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_prods.shape
# Out:
# (49672, 6)

# %%
df_prods.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# df_merged_large = df_ords.merge(df_ords_prior, on ='order_id', indicator = True)

# %%
df_merged_large
# Out:
#           Unnamed: 0  order_id  user_id  order_number  orders_day_of_the_week  \
# 0                  0   2539329        1             1                       2
# 1                  0   2539329        1             1                       2
# 2                  0   2539329        1             1                       2
# 3                  0   2539329        1             1                       2
# 4                  0   2539329        1             1                       2
# ...              ...       ...      ...           ...                     ...
# 32434484     3421081   2977660   206209            13                       1
# 32434485     3421081   2977660   206209            13                       1
# 32434486     3421081   2977660   206209            13                       1
# 32434487     3421081   2977660   206209            13                       1
# 32434488     3421081   2977660   206209            13                       1
#
# ...

# %%
#Drop '_merge' column from frist merge, otherwise error. With df.drop(columns = ['variable'])
df_merged_large_clean = df_merged_large.drop(columns = ['_merge'])
df_merged_large_clean
# Out:
#           Unnamed: 0  order_id  user_id  order_number  orders_day_of_the_week  \
# 0                  0   2539329        1             1                       2
# 1                  0   2539329        1             1                       2
# 2                  0   2539329        1             1                       2
# 3                  0   2539329        1             1                       2
# 4                  0   2539329        1             1                       2
# ...              ...       ...      ...           ...                     ...
# 32434484     3421081   2977660   206209            13                       1
# 32434485     3421081   2977660   206209            13                       1
# 32434486     3421081   2977660   206209            13                       1
# 32434487     3421081   2977660   206209            13                       1
# 32434488     3421081   2977660   206209            13                       1
#
# ...

# %%
df_ords_prods_merged = df_merged_large_clean.merge(df_prods, on = 'product_id', indicator = True)

# %%
df_ords_prods_merged
# Out:
#           Unnamed: 0_x  order_id  user_id  order_number  \
# 0                    0   2539329        1             1
# 1                    1   2398795        1             2
# 2                    2    473747        1             3
# 3                    3   2254736        1             4
# 4                    4    431534        1             5
# ...                ...       ...      ...           ...
# 32404854       3360493   1320836   202557            17
# 32404855       3360494     31526   202557            18
# 32404856       3376038    758936   203436             1
# 32404857       3376039   2745165   203436             2
# 32404858       3408036   3093936   205420             1
#
#           orders_day_of_the_week  order_hour_of_day  days_since_prior_order  \
# 0                              2                  8                     NaN
# 1                              3                  7                    15.0
# ...

# %%
#Drop both unnamed columns. With df.drop(columns = ['variable'])
df_ords_prods_merged_clean = df_ords_prods_merged.drop(columns = ['_merge', 'Unnamed: 0_x', 'Unnamed: 0_y'])
df_ords_prods_merged_clean
# Out:
#           order_id  user_id  order_number  orders_day_of_the_week  \
# 0          2539329        1             1                       2
# 1          2398795        1             2                       3
# 2           473747        1             3                       3
# 3          2254736        1             4                       4
# 4           431534        1             5                       4
# ...            ...      ...           ...                     ...
# 32404854   1320836   202557            17                       2
# 32404855     31526   202557            18                       5
# 32404856    758936   203436             1                       2
# 32404857   2745165   203436             2                       3
# 32404858   3093936   205420             1                       4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# ...

# %%
df_ords_prods_merged_clean.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined_cleaned.pkl'))
