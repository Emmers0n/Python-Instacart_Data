# %%
#Import Libraries
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import scipy

# %%
path = r'/Users/tilemmerichs/Desktop/Insta Basket Analysis'

# %%
#Import Dataframe
df_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'Ords_prods_customer_merged.pkl'))

# %%
df_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_the_week  order_hour_of_day  \
# 0   2539329        1             1                       2                  8
# 1   2398795        1             2                       3                  7
# 2    473747        1             3                       3                 12
# 3   2254736        1             4                       4                  7
# 4    431534        1             5                       4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  First Name  Surname  Gender    STATE Age date_joined  \
# ...

# %%
#Task 3: Create histogram about the hour of the order
hist = df_merge['order_hour_of_day'].plot.hist(bins=24)

# %% [markdown]
# The histogram shows that most orders happen around noon time

# %%
#Task 4
bar = df_merge['loyalty_flag'].value_counts().sort_index().plot.bar()

# %%
#Creating a sample
np.random.seed(4)
dev = np.random.rand(len(df_merge)) <= 0.7

# %%
big = df_merge[dev]
small = df_merge[~dev]

# %%
df_small = small[['prices', 'order_hour_of_day']]

# %%
#Create line chart for Task 5
line = sns.lineplot(data = df_small, x = 'order_hour_of_day', y = 'prices')

# %% [markdown]
# Average order value is the highest around 2:00 am

# %%
#Creating dataframe for Task 6: Connection between Age and number of children
df_small_2 = small[['children', 'Age']]

# %%
line2 = sns.lineplot(data = df_small_2, x = 'Age', y = 'children')

# %% [markdown]
# No connection between Age and number of children visible

# %%
scatter = sns.scatterplot(x='Age', y='income', data=df_merge)

# %%
scatter.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'scatterplot.png'))

# %%
line2.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'line2.png'))

# %%
line.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'line.png'))

# %%
bar.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'bar.png'))

# %%
hist.figure.savefig(os.path.join(path, '04 Analysis', 'Visualizations', 'hist.png'))
